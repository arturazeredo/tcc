# %%
import sys
sys.path.insert(0, '.././')  # add grandparent directory to sys.path

# %%
from src.mediapipe import GooMedia
import cv2
import numpy as np
from src.visualize import *
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from src.utils import image_resize
from src.geometry import get_points_media
from src.geometry import distance_entre_points
from PIL import Image

# %%
#%matplotlib qt

# %%
pface = GooMedia(1080) # Extrator dos pontos

# %% [markdown]
# # looking right - mid screen

# %%
image = cv2.imread(r"..\images\inputs\9pointscamera\9points_x17_y50.jpg")
image_resize , landmask = pface.extract(image)
points = pface.points_normalize(landmask, image.shape, index=0)

# %%
iris= get_points_media(points, 'iris_analyser3')

# %%
points_eye = draw_face_one_color(image_resize, iris)

# %%
# Enumerate the iris points and plot them on points_eye
plt.figure()
for i, point in enumerate(iris):
    plt.text(point[0], point[1], str(i), color='red', fontsize=10)

# %%
plt.imshow(points_eye[...,::-1])
plt.show()

# %% [markdown]
# 'iris_analyser2' method is shown below:

# %% [markdown]
# ![alt text](vectors/iris_analyser3.png)

# %%
print(distance_entre_points(iris, 0, 1))
# Out:
# 10.198039027185569

# %%
print(distance_entre_points(iris, 2, 3))
# Out:
# 12.36931687685298

# %%
plt.figure()
cv2.line(image_resize, iris[0], iris[1], color=(0, 0, 255), thickness=1)
plt.imshow(points_eye[...,::-1]) 
plt.show()

# %%
print(distance_entre_points(iris, 5, 4))
# Out:
# 13.152946437965905

# %%
print(distance_entre_points(iris, 7, 6))
# Out:
# 9.219544457292887

# %%
plt.figure()
cv2.line(image_resize, iris[6], iris[7], color=(0, 0, 255), thickness=1)
plt.imshow(points_eye[...,::-1]) 
plt.show()

# %% [markdown]
# # looking left - mid screen

# %%
image = cv2.imread(r"..\images\inputs\9pointscamera\9points_x83_y50.jpg")
image_resize , landmask = pface.extract(image)
points = pface.points_normalize(landmask, image.shape, index=0)

# %%
iris= get_points_media(points, 'iris_analyser3')

# %%
points_eye = draw_face_one_color(image_resize, iris)

# %%
# Enumerate the iris points and plot them on points_eye
plt.figure()
for i, point in enumerate(iris):
    plt.text(point[0], point[1], str(i), color='red', fontsize=10)

# %%
plt.imshow(points_eye[...,::-1])
plt.show()

# %% [markdown]
# 'iris_analyser2' method is shown below:

# %% [markdown]
# ![alt text](vectors/iris_analyser3.png)

# %%
print(distance_entre_points(iris, 0, 1))
# Out:
# 11.180339887498949

# %%
print(distance_entre_points(iris, 2, 3))
# Out:
# 9.848857801796104

# %%
plt.figure()
cv2.line(image_resize, iris[0], iris[1], color=(0, 0, 255), thickness=1)
plt.imshow(points_eye[...,::-1]) 
plt.show()

# %%
print(distance_entre_points(iris, 5, 4))
# Out:
# 15.297058540778355

# %%
print(distance_entre_points(iris, 7, 6))
# Out:
# 8.54400374531753

# %%
plt.figure()
cv2.line(image_resize, iris[6], iris[7], color=(0, 0, 255), thickness=1)
plt.imshow(points_eye[...,::-1]) 
plt.show()

# %% [markdown]
# # looking center - mid screen

# %%
image = cv2.imread(r"..\images\inputs\9pointscamera\9points_x50_y50.jpg")
image_resize , landmask = pface.extract(image)
points = pface.points_normalize(landmask, image.shape, index=0)

# %%
iris= get_points_media(points, 'iris_analyser3')

# %%
points_eye = draw_face_one_color(image_resize, iris)

# %%
# Enumerate the iris points and plot them on points_eye
plt.figure()
for i, point in enumerate(iris):
    plt.text(point[0], point[1], str(i), color='red', fontsize=6)

# %%
plt.imshow(points_eye[...,::-1])
plt.show()

# %% [markdown]
# 'iris_analyser2' method is shown below:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(distance_entre_points(iris, 0, 1))
# Out:
# 11.180339887498949

# %%
print(distance_entre_points(iris, 2, 3))
# Out:
# 10.44030650891055

# %%
plt.figure()
cv2.line(image_resize, iris[0], iris[1], color=(0, 0, 255), thickness=1)
plt.imshow(points_eye[...,::-1]) 
plt.show()

# %%
print(distance_entre_points(iris, 5, 4))
# Out:
# 14.317821063276353

# %%
print(distance_entre_points(iris, 7, 6))
# Out:
# 9.486832980505138

# %%
plt.figure()
cv2.line(image_resize, iris[6], iris[7], color=(0, 0, 255), thickness=1)
plt.imshow(points_eye[...,::-1]) 
plt.show()

# %% [markdown]
# # Comparações

# %% [markdown]
# ## Direita - Centro

# %% [markdown]
# Tomando as distâncias do olhar ao centro como base, a análise de duplas que faz sentido com a lógica é:
#
# | DUPLA VETORIAL | DIREITA | CENTRO |
# |----------------|---------|--------|
# | 0-1            | <       | >      |
# | 2-3            | >       | <      |
# | 4-5            | <       | >      |
# | 6-7            | >       | <      |
