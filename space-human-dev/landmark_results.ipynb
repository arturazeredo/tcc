# %%
 # Importing libraries
import cv2 as cv
import numpy as np 
import mediapipe as mp
import math
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# %%
model_path = 'face_landmarker_v2_with_blendshapes.task'

# %%
import mediapipe as mp

BaseOptions = mp.tasks.BaseOptions
FaceLandmarker = mp.tasks.vision.FaceLandmarker
FaceLandmarkerOptions = mp.tasks.vision.FaceLandmarkerOptions
VisionRunningMode = mp.tasks.vision.RunningMode

options = FaceLandmarkerOptions(
    base_options=BaseOptions(model_asset_path=model_path),
    running_mode=VisionRunningMode.IMAGE)

# %%
# Load the input image from an image file.
mp_image = mp.Image.create_from_file(r'images\inputs\5pointscamera\5points_x83_y17.jpg')

# %%
with FaceLandmarker.create_from_options(options) as landmarker:

# Perform face landmarking on the provided single image.
# The face landmarker must be created with the image mode.
    face_landmarker_result = landmarker.detect(mp_image)
# Out:
# c:\Users\artur\.conda\envs\space_human\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
print(face_landmarker_result)
# Out:
# FaceLandmarkerResult(face_landmarks=[[NormalizedLandmark(x=0.5383308529853821, y=0.5947310924530029, z=-0.05257447436451912, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5360555648803711, y=0.5440277457237244, z=-0.10002345591783524, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5366074442863464, y=0.5585139989852905, z=-0.05233286693692207, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5183399319648743, y=0.49318820238113403, z=-0.07453233003616333, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5355378985404968, y=0.5280711054801941, z=-0.10610520094633102, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5347638726234436, y=0.5075854659080505, z=-0.09846590459346771, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5334604978561401, y=0.4586375653743744, z=-0.04840502887964249, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.40586185455322266, y=0.45648255944252014, z=0.026244046166539192, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5321438312530518, y=0.4244735538959503, z=-0.035764649510383606, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5316640138626099, y=0.40478265285491943, z=-0.03926776722073555, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5289431214332581, y=0.33022627234458923, z=-0.015684137120842934, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5384706258773804, y=0.6001669764518738, z=-0.050221193581819534, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5386110544204712, y=0.6054573655128479, z=-0.04401647299528122, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5382214188575745, y=0.6093738079071045, z=-0.035579029470682144, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5379785299301147, y=0.6094472408294678, z=-0.0334896482527256, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5380473136901855, y=0.61572265625, z=-0.036580391228199005, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5382810831069946, y=0.6237624287605286, z=-0.040977947413921356, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5380080938339233, y=0.6322606205940247, z=-0.03910168632864952, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5385098457336426, y=0.6487538814544678, z=-0.021959669888019562, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5362998843193054, y=0.5521334409713745, z=-0.09039564430713654, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5181572437286377, y=0.5519667863845825, z=-0.06484318524599075, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.33635222911834717, y=0.4046984910964966, z=0.11550994217395782, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4559346139431, y=0.4670673608779907, z=0.007424692623317242, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4374712109565735, y=0.4693892300128937, z=0.008261347189545631, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4198416471481323, y=0.46968236565589905, z=0.013061752542853355, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.3980567455291748, y=0.4629250168800354, z=0.028713198378682137, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4722759425640106, y=0.4628292918205261, z=0.00906776450574398, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4254377484321594, y=0.42823484539985657, z=-0.0002630127710290253, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.44697096943855286, y=0.428635835647583, z=0.0003439526481088251, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.40675508975982666, y=0.43184980750083923, z=0.00534469448029995, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.39534521102905273, y=0.43784552812576294, z=0.013188127428293228, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.38262611627578735, y=0.4733368456363678, z=0.037641555070877075, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.47009873390197754, y=0.6750425696372986, z=-0.001450057839974761, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.3995298147201538, y=0.4533122777 ...
